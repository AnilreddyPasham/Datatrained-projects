# %%
import pandas as pd
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas_profiling
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\practice\census.csv")

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df['Income'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
def label_fix(label):
    if label==' <=50K':
        return 0
    else:
        return 1

# %%
df['Income'] = df['Income'].apply(label_fix)

# %%
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Fnlwgt'}>,
#         <AxesSubplot:title={'center':'Education_num'}>],
#        [<AxesSubplot:title={'center':'Capital_gain'}>,
#         <AxesSubplot:title={'center':'Capital_loss'}>,
#         <AxesSubplot:title={'center':'Hours_per_week'}>],
#        [<AxesSubplot:title={'center':'Income'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States       0
# ...

# %%
df.drop(columns=['Education'], inplace=True)

# %%
data = pd.get_dummies(df, columns=['Workclass', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country'], drop_first=False)

# %%
data = pd.get_dummies(data, columns=['Income'], drop_first=True)

# %%
data.head()
# Out:
#    Age  Fnlwgt  Education_num  Capital_gain  Capital_loss  Hours_per_week  \
# 0   50   83311             13             0             0              13
# 1   38  215646              9             0             0              40
# 2   53  234721              7             0             0              40
# 3   28  338409             13             0             0              40
# 4   37  284582             14             0             0              40
#
#    Workclass_ ?  Workclass_ Federal-gov  Workclass_ Local-gov  \
# 0             0                       0                     0
# 1             0                       0                     0
# 2             0                       0                     0
# 3             0                       0                     0
# 4             0                       0                     0
#
#    Workclass_ Never-worked  Workclass_ Private  Workclass_ Self-emp-inc  \
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Fnlwgt', 'Education_num', 'Capital_gain', 'Capital_loss',
#        'Hours_per_week', 'Workclass_ ?', 'Workclass_ Federal-gov',
#        'Workclass_ Local-gov', 'Workclass_ Never-worked', 'Workclass_ Private',
#        'Workclass_ Self-emp-inc', 'Workclass_ Self-emp-not-inc',
#        'Workclass_ State-gov', 'Workclass_ Without-pay',
#        'Marital_status_ Divorced', 'Marital_status_ Married-AF-spouse',
#        'Marital_status_ Married-civ-spouse',
#        'Marital_status_ Married-spouse-absent',
#        'Marital_status_ Never-married', 'Marital_status_ Separated',
#        'Marital_status_ Widowed', 'Occupation_ ?', 'Occupation_ Adm-clerical',
#        'Occupation_ Armed-Forces', 'Occupation_ Craft-repair',
#        'Occupation_ Exec-managerial', 'Occupation_ Farming-fishing',
#        'Occupation_ Handlers-cleaners', 'Occupation_ Machine-op-inspct',
#        'Occupation_ Other-service', 'Occupation_ Priv-house-serv',
# ...

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(data.iloc[:,[0, 1, 2, 3, 4, 5, -1]].astype(float).corr(),linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('WorkClass Correlation', y=1.05, size=15)
sns.heatmap(
    data.loc[:, data.columns.str.contains('Workclass') | data.columns.str.contains('Income')].corr(),
    linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'WorkClass Correlation'}>

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Marital Correlation', y=1.05, size=15)
sns.heatmap(
    data.loc[:, data.columns.str.contains('Marital_status') | data.columns.str.contains('Income')].corr(),
    linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Marital Correlation'}>

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Occupation Correlation', y=1.05, size=15)
sns.heatmap(
    data.loc[:, data.columns.str.contains('Occupation') | data.columns.str.contains('Income')].corr(),
    linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Occupation Correlation'}>

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Relationship Correlation', y=1.05, size=15)
sns.heatmap(
    data.loc[:, data.columns.str.contains('Income') | data.columns.str.contains('Relationship')].corr(),
    linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Relationship Correlation'}>

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Marital / Relationship / Sex Co-Correlation', y=1.05, size=15)
sns.heatmap(
    data.loc[:, data.columns.str.contains('Marital_status') | data.columns.str.contains('Relationship') | data.columns.str.contains('Sex') | data.columns.str.contains('Income')].corr() ,
    linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Marital / Relationship / Sex Co-Correlation'}>

# %%
data = data.loc[:, (data.columns.str.contains('Marital_status') == False) & (data.columns.str.contains('Sex') == False)]

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Workclass / Occupation Co-Correlation', y=1.05, size=15)
sns.heatmap(
    data.loc[:, data.columns.str.contains('Workclass') | data.columns.str.contains('Occupation') | data.columns.str.contains('Income')].corr(),
    linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=False)
# Out:
# <AxesSubplot:title={'center':'Workclass / Occupation Co-Correlation'}>

# %%
data = data.loc[:, data.columns.str.contains('Workclass') == False]

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Race / Native Country Co-Correlation', y=1.05, size=15)
sns.heatmap(
    data.loc[:, data.columns.str.contains('Race') | data.columns.str.contains('Native') | data.columns.str.contains('Income')].corr(),
    linewidths=0.1,vmax=1.0, square=False, cmap=colormap, linecolor='white', annot=False)
# Out:
# <AxesSubplot:title={'center':'Race / Native Country Co-Correlation'}>

# %%
data = data.loc[:, data.columns.str.contains('Native') == False]

# %%
data.drop(columns=['Fnlwgt'], inplace=True)

# %%
data.head()
# Out:
#    Age  Education_num  Capital_gain  Capital_loss  Hours_per_week  \
# 0   50             13             0             0              13
# 1   38              9             0             0              40
# 2   53              7             0             0              40
# 3   28             13             0             0              40
# 4   37             14             0             0              40
#
#    Occupation_ ?  Occupation_ Adm-clerical  Occupation_ Armed-Forces  \
# 0              0                         0                         0
# 1              0                         0                         0
# 2              0                         0                         0
# 3              0                         0                         0
# 4              0                         0                         0
#
#    Occupation_ Craft-repair  Occupation_ Exec-managerial  \
# 0                         0                            1
# ...

# %%
X = data.iloc[:, 0:-1]
y = data.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn import tree

# %%
decision_tree = tree.DecisionTreeClassifier(max_depth = 4)

# %%
decision_tree.fit(X_train, y_train)

y_pred_tree = decision_tree.predict(X_test)

# %%
'Accuracy of our tree model'
f'{round(accuracy_score(y_test, y_pred_tree) * 100, 2)} %'
# Out:
# '84.31 %'
